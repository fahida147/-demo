# %% [markdown]
# # Laon default prediction

# %%
import pandas as pd

# %%
#Dataset
data=pd.read_csv(r"C:\Users\abdur\Downloads\archive (3).zip")
data
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
data.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
data.shape
# Out:
# (4269, 13)

# %%
data.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
data.tail()
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
# ...

# %%
#check datatype
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
data.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
#statistical summary
data.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
#correlation
data.select_dtypes(include='number').corr()
# Out:
#                             loan_id   no_of_dependents   income_annum  \
# loan_id                    1.000000           0.005326       0.012592
#  no_of_dependents          0.005326           1.000000       0.007266
#  income_annum              0.012592           0.007266       1.000000
#  loan_amount               0.008170          -0.003366       0.927470
#  loan_term                 0.009809          -0.020111       0.011488
#  cibil_score               0.016323          -0.009998      -0.023034
#  residential_assets_value  0.020936           0.007376       0.636841
#  commercial_assets_value   0.018595          -0.001531       0.640328
#  luxury_assets_value      -0.000862           0.002817       0.929145
#  bank_asset_value          0.010765           0.011163       0.851093
#
#                             loan_amount   loan_term   cibil_score  \
# loan_id                        0.008170    0.009809      0.016323
# ...

# %%
#string columns
data.select_dtypes(include='object').columns
# Out:
# Index([' education', ' self_employed', ' loan_status'], dtype='object')

# %%
import seaborn as sns

# %%
#outlier handling
sns.boxplot(data)
# Out:
# <Axes: >

# %%
sns.boxplot(data[' residential_assets_value'])
# Out:
# <Axes: >

# %%
sns.boxplot(data[' commercial_assets_value'])
# Out:
# <Axes: >

# %%
sns.boxplot(data[' bank_asset_value'])
# Out:
# <Axes: >

# %%
Q1=data[' residential_assets_value'].quantile(.25)
Q3=data[' residential_assets_value'].quantile(.75)
print(Q1)
print(Q3)
IQR=Q3-Q1
print(IQR)
# Out:
# 2200000.0
# 11300000.0
# 9100000.0

# %%
outliers=data[(data[' residential_assets_value']<(Q1-(1.5*IQR)))|
(data[' residential_assets_value']>(Q3+(1.5*IQR)))]
outliers.shape
# Out:
# (52, 13)

# %%
outliers[' residential_assets_value']
# Out:
# 82      25500000
# 98      25900000
# 123     26800000
# 228     25500000
# 262     25600000
# 693     25400000
# 714     28300000
# 781     26300000
# 892     27600000
# 905     28700000
# 919     25300000
# 924     25800000
# 953     25500000
# 956     25300000
# 987     28200000
# 997     25200000
# 1002    25800000
# 1397    25700000
# 1419    25500000
# 1468    27000000
# 1591    28500000
# 1625    26300000
# 1965    28400000
# 1997    27000000
# 2185    25900000
# 2318    28500000
# 2384    26600000
# 2412    26200000
# 2586    28000000
# 2715    25800000
# 2818    25500000
# 2828    26900000
# 2922    25200000
# 2927    27600000
# 2930    25300000
# 2940    26100000
# 3119    29100000
# 3157    25400000
# 3234    28200000
# 3310    25100000
# 3498    25600000
# 3631    25400000
# 3763    26100000
# 3782    27500000
# 3860    25000000
# 3868    25500000
# 3872    25400000
# 3880    26200000
# 4027    25100000
# 4042    27400000
# 4074    27300000
# 4237    26200000
# ...

# %%
#replacing the oulier using iqr
new_data=data[~(data[' residential_assets_value']<(Q1-(1.5*IQR)))|
(data[' residential_assets_value']>(Q3+(1.5*IQR)))]
outliers.shape
# Out:
# (52, 13)

# %%
Q1=data[' commercial_assets_value' ].quantile(.25)
Q3=data[' commercial_assets_value' ].quantile(.75)
print(Q1)
print(Q3)
IQR=Q3-Q1
print(IQR)
# Out:
# 1300000.0
# 7600000.0
# 6300000.0

# %%
outliers=data[(data[' commercial_assets_value' ]<(Q1-(1.5*IQR)))|
(data[' commercial_assets_value']>(Q3+(1.5*IQR)))]
outliers.shape
# Out:
# (37, 13)

# %%
outliers[' commercial_assets_value']
# Out:
# 0       17600000
# 157     18700000
# 231     17500000
# 258     19000000
# 323     17200000
# 367     18500000
# 554     18800000
# 791     17800000
# 895     18500000
# 905     17900000
# 1029    18300000
# 1131    17300000
# 1194    17300000
# 1254    18900000
# 1272    18400000
# 1304    18200000
# 1609    17300000
# 1761    19000000
# 1768    19400000
# 1812    17800000
# 2004    17500000
# 2302    17900000
# 2349    17400000
# 2914    18500000
# 2933    17600000
# 2940    19000000
# 2976    17700000
# 3000    18800000
# 3439    18400000
# 3541    17200000
# 3790    18400000
# 3827    17700000
# 3882    18500000
# 3949    17600000
# 4010    17600000
# 4120    17900000
# 4205    17600000
# Name:  commercial_assets_value, dtype: int64

# %%
new_data=data[~(data[' commercial_assets_value']<(Q1-(1.5*IQR)))|
(data[' commercial_assets_value']>(Q3+(1.5*IQR)))]
outliers.shape
# Out:
# (37, 13)

# %%
Q1=data[' bank_asset_value' ].quantile(.25)
Q3=data[' bank_asset_value'].quantile(.75)
print(Q1)
print(Q3)
IQR=Q3-Q1
print(IQR)
# Out:
# 2300000.0
# 7100000.0
# 4800000.0

# %%
outliers=data[(data[ ' bank_asset_value']<(Q1-(1.5*IQR)))|
(data[' bank_asset_value']>(Q3+(1.5*IQR)))]
outliers.shape
# Out:
# (5, 13)

# %%
outliers[' bank_asset_value']
# Out:
# 200     14400000
# 1272    14700000
# 1633    14600000
# 1674    14600000
# 1805    14700000
# Name:  bank_asset_value, dtype: int64

# %%
new_data=data[~(data[' bank_asset_value']<(Q1-(1.5*IQR)))|
(data[' bank_asset_value']>(Q3+(1.5*IQR)))]
outliers.shape
# Out:
# (5, 13)

# %%
#check the new outlier status
new_data.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
import sklearn

# %%
#encoding
from sklearn .preprocessing import LabelEncoder

# %%
new_data[' education']=LabelEncoder().fit_transform(new_data[' education'])
new_data[' self_employed']=LabelEncoder().fit_transform(new_data[' self_employed'])
new_data[' loan_status']=LabelEncoder().fit_transform(new_data[' loan_status'])

# %%
new_data.describe()
# Out:
#            loan_id   no_of_dependents    education   self_employed  \
# count  4269.000000        4269.000000  4269.000000     4269.000000
# mean   2135.000000           2.498712     0.497775        0.503631
# std    1232.498479           1.695910     0.500054        0.500045
# min       1.000000           0.000000     0.000000        0.000000
# 25%    1068.000000           1.000000     0.000000        0.000000
# 50%    2135.000000           3.000000     0.000000        1.000000
# 75%    3202.000000           4.000000     1.000000        1.000000
# max    4269.000000           5.000000     1.000000        1.000000
#
#         income_annum   loan_amount    loan_term   cibil_score  \
# count   4.269000e+03  4.269000e+03  4269.000000   4269.000000
# mean    5.059124e+06  1.513345e+07    10.900445    599.936051
# std     2.806840e+06  9.043363e+06     5.709187    172.430401
# min     2.000000e+05  3.000000e+05     2.000000    300.000000
# ...

# %%
new_data[' education'].value_counts()
# Out:
#  education
# 0    2144
# 1    2125
# Name: count, dtype: int64

# %%
new_data[' self_employed'].value_counts()
# Out:
#  self_employed
# 1    2150
# 0    2119
# Name: count, dtype: int64

# %%
new_data[' loan_status'].value_counts()
# Out:
#  loan_status
# 0    2656
# 1    1613
# Name: count, dtype: int64

# %%
#dep and inde variables
x=new_data.drop([' loan_status','loan_id'], axis=1)
y=new_data[' loan_status']
x
# Out:
#        no_of_dependents   education   self_employed   income_annum  \
# 0                     2           0               0        9600000
# 1                     0           1               1        4100000
# 2                     3           0               0        9100000
# 3                     3           0               0        8200000
# 4                     5           1               1        9800000
# ...                 ...         ...             ...            ...
# 4264                  5           0               1        1000000
# 4265                  0           1               1        3300000
# 4266                  2           1               0        6500000
# 4267                  1           1               0        4100000
# 4268                  1           0               0        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0         29900000          12           778                    2400000
# ...

# %%
#splitting
from sklearn.model_selection import  train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=.3)

# %%
#scaling
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
ss=st.fit_transform(new_data)
ss
# Out:
# array([[-1.73164513, -0.2941017 , -0.99555917, ...,  0.83202837,
#          0.93030441, -0.77929726],
#        [-1.73083367, -1.4735476 ,  1.00446064, ..., -0.69499321,
#         -0.51593638,  1.28320739],
#        [-1.73002222,  0.29562125, -0.99555917, ...,  1.99651964,
#          2.40731629,  1.28320739],
#        ...,
#        [ 1.73002222, -0.2941017 ,  1.00446064, ...,  0.3266831 ,
#          0.71490685,  1.28320739],
#        [ 1.73083367, -0.88382465,  1.00446064, ..., -0.11274758,
#          0.25334064, -0.77929726],
#        [ 1.73164513, -0.88382465, -0.99555917, ...,  2.26017804,
#          2.16114764, -0.77929726]])

# %%
#1

# %% [markdown]
# #  LogisticRegression

# %%
from  sklearn.linear_model import LogisticRegression

# %%
#model building
log_model=LogisticRegression()  #initialize the model
log_model.fit(x_train,y_train)  #train the model
# Out:
# LogisticRegression()

# %%
#check model score
log_train_acc=log_model.score(x_train,y_train)
log_test_acc=log_model.score(x_test,y_test)
print('train accuracy of logistic :',log_train_acc)
print('test accuracy of logistic:',log_test_acc)
# Out:
# train accuracy of logistic : 0.6164658634538153
# test accuracy of logistic: 0.6323185011709602

# %%
#predict
y_pred=log_model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#confusion matrix
from sklearn .metrics import confusion_matrix

# %%
confus_matrx=confusion_matrix(y_test,y_pred)
confus_matrx
# Out:
# array([[804,   9],
#        [462,   6]], dtype=int64)

# %%
#ploting confusion matrix
import matplotlib.pyplot as plt
import seaborn  as sns

# %%
plt.figure(figsize=(3,3))
sns.heatmap(confus_matrx,annot=True)
plt.xlabel('predicted')
plt.ylabel('actual')
# Out:
# Text(8.222222222222223, 0.5, 'actual')

# %%
#classification report
from sklearn.metrics import  classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.99      0.77       813
#            1       0.40      0.01      0.02       468
#
#     accuracy                           0.63      1281
#    macro avg       0.52      0.50      0.40      1281
# weighted avg       0.55      0.63      0.50      1281

# %%
#cross validation
from sklearn.model_selection import cross_val_score

# %%
#hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# %%
log_score=cross_val_score(log_model,x_train,y_train,cv=5)
print(f'CV score:{log_score}')
print('mean CV score:',log_score.mean())
# Out:
# CV score:[0.6187291  0.60200669 0.73578595 0.61474037 0.60971524]
# mean CV score: 0.6361954701041439

# %%
param={'C':[1,5,10]}
log_grid=GridSearchCV(log_model,param,cv=5)
log_grid.fit(x_train,y_train)
print('best  CV parameter :',log_grid.best_params_)
print('best CV score:',log_grid.best_score_)
# Out:
# best  CV parameter : {'C': 1}
# best CV score: 0.6361954701041439

# %%
#2

# %% [markdown]
# #  DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#model building
dec_model=DecisionTreeClassifier(max_depth=10)
dec_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
#check model score
dec_train_acc=dec_model.score(x_train,y_train)
dec_test_acc=dec_model.score(x_test,y_test)
print('train accuracy of decisiontree:',dec_train_acc)
print('test accuracy of decisiontree:',dec_test_acc)
# Out:
# train accuracy of decisiontree: 0.9963186077643909
# test accuracy of decisiontree: 0.9695550351288056

# %%
from sklearn import tree

# %%
#build model with another parameters
dec_model2=DecisionTreeClassifier(max_depth=8,min_samples_leaf=10,
                                  min_samples_split=10,criterion='gini')
dec_model2.fit(x_train,y_train)
dec_train_acc2=dec_model2.score(x_train,y_train)
dec_test_acc2=dec_model2.score(x_test,y_test)
print('train accuracy of decisiontree:',dec_train_acc2)
print('test accuracy of decisiontree:',dec_test_acc2)
# Out:
# train accuracy of decisiontree: 0.9849397590361446
# test accuracy of decisiontree: 0.9664324746291959

# %%
dec_model3=DecisionTreeClassifier(max_depth=6,min_samples_leaf=10,
                                  min_samples_split=10,criterion='gini')
dec_model3.fit(x_train,y_train)
dec_train_acc3=dec_model3.score(x_train,y_train)
dec_test_acc3=dec_model3.score(x_test,y_test)
print('train accuracy of decisiontree:',dec_train_acc3)
print('test accuracy of decisiontree:',dec_test_acc3)
# Out:
# train accuracy of decisiontree: 0.9802543507362784
# test accuracy of decisiontree: 0.9633099141295862

# %%
#prediction
y_pred=dec_model2.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
#classification report
from sklearn.metrics  import  classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       813
#            1       0.98      0.93      0.95       468
#
#     accuracy                           0.97      1281
#    macro avg       0.97      0.96      0.96      1281
# weighted avg       0.97      0.97      0.97      1281

# %%
#cross validation 
dec_score=cross_val_score(dec_model2,x_train,y_train,cv=5)
print(f'dec_CV score:{dec_score}')
print('dec_mean score:',dec_score.mean())
# Out:
# dec_CV score:[0.97491639 0.97324415 0.98494983 0.9798995  0.97822446]
# dec_mean score: 0.9782468641983607

# %%
#hyper tuninh
d_param={'max_depth':[10,8,5],
         'min_samples_leaf':[10,5,15],
         'min_samples_split':[10,20,15]}
dec_grid=GridSearchCV(dec_model2,d_param,cv=5)
dec_grid.fit(x_train,y_train)
print('Best decision parameter :',dec_grid.best_params_)
print('Best decision score:',dec_grid.best_score_)
# Out:
# Best decision parameter : {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# Best decision score: 0.9789163207341053

# %%
#3

# %% [markdown]
# #  RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_model=RandomForestClassifier(max_depth=10,min_samples_leaf=15,min_samples_split=15,
                                    n_estimators=47,random_state=34)
random_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=15, min_samples_split=15,
#                        n_estimators=47, random_state=34)

# %%
random_train_acc=random_model.score(x_train,y_train)
random_test_acc=random_model.score(x_test,y_test)
print('train accuracy of randomforest:',random_train_acc)
print('test accuracy of randomforest:',random_test_acc)
# Out:
# train accuracy of randomforest: 0.9892904953145917
# test accuracy of randomforest: 0.9687743950039032

# %%
#model build  with different parameters
random_model2=RandomForestClassifier(max_depth=6,min_samples_leaf=10,min_samples_split=10,
                                     n_estimators=200,random_state=34)
random_model2.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=10, min_samples_split=10,
#                        n_estimators=200, random_state=34)

# %%
random_train_acc2=random_model2.score(x_train,y_train)
random_test_acc2=random_model2.score(x_test,y_test)
print('train accuracy of randomforest:',random_train_acc2)
print('test accuracy of randomforest:',random_test_acc2)
# Out:
# train accuracy of randomforest: 0.9896251673360107
# test accuracy of randomforest: 0.9726775956284153

# %%
y_pred=random_model2.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       813
#            1       0.96      0.96      0.96       468
#
#     accuracy                           0.97      1281
#    macro avg       0.97      0.97      0.97      1281
# weighted avg       0.97      0.97      0.97      1281

# %%
random_score=cross_val_score(random_model2,x_train,y_train,cv=5)
print(f'random_CV score:{random_score}')
print('random_mean score:',random_score.mean())
# Out:
# random_CV score:[0.97157191 0.95819398 0.97826087 0.97487437 0.9798995 ]
# random_mean score: 0.9725601250399153

# %%
rf_param={'n_estimators':[5,10,200],
          'min_samples_leaf':[10,5,15],
          'min_samples_split':[5,10,15]}
random_grid=GridSearchCV(random_model2,rf_param,cv=5)
random_grid.fit(x_train,y_train)
print('best random parameter :',random_grid.best_params_)
print('best random score:',random_grid.best_score_)
# Out:
# best random parameter : {'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 200}
# best random score: 0.9725601250399153

# %%
import joblib

# %%
joblib.dump(random_model2,r"C:\Users\abdur\Downloads\project_rand_model2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 joblib.dump(random_model2,r"C:\Users\abdur\Downloads\project_rand_model2")
#
# NameError: name 'random_model2' is not defined

# %%
model2_random=joblib.load(r"C:\Users\abdur\Downloads\project_rand_model2")

# %%
model2_random.predict([[2,0,41,12,50,71,23,80,90,20,8]])
# Out:
# C:\Users\abdur\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
#4

# %% [markdown]
# #  Kneighbors

# %%
from sklearn .neighbors import KNeighborsClassifier

# %%
k_model=KNeighborsClassifier(n_neighbors=10)
k_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
#score
k_train_acc=k_model.score(x_train,y_train)
k_test_acc=k_model.score(x_test,y_test)
print('train accuracy of kneighbors:',k_train_acc)
print('test accuracy of kneighbors :',k_test_acc)
# Out:
# train accuracy of kneighbors: 0.6663319946452476
# test accuracy of kneighbors : 0.5823575331772053

# %%
#prediction
y_pred=k_model.predict(x_test)
y_pred
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.83      0.72       813
#            1       0.34      0.15      0.21       468
#
#     accuracy                           0.58      1281
#    macro avg       0.48      0.49      0.46      1281
# weighted avg       0.52      0.58      0.53      1281

# %%
#cross validation
knn_score=cross_val_score(k_model,x_train,y_train,cv=5)
print(f'knn_CV score:{knn_score}')
print('knn_mean score:',knn_score.mean())
# Out:
# knn_CV score:[0.60535117 0.59698997 0.58026756 0.58291457 0.59966499]
# knn_mean score: 0.5930376520282572

# %%
#hyperparameter tuning
kn_param={'n_neighbors':[10,15,20]}
knn_grid=GridSearchCV(k_model,kn_param,cv=5)
knn_grid.fit(x_train,y_train)
print('best knn parameter :',knn_grid.best_params_)
print('best knn score:',knn_grid.best_score_)
# Out:
# best knn parameter : {'n_neighbors': 20}
# best knn score: 0.6000666655462374

# %%
#5

# %% [markdown]
# #  Naive Bayes

# %%
from sklearn .naive_bayes import GaussianNB

# %%
nb_model=GaussianNB()
nb_model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
nb_train_acc=nb_model.score(x_train,y_train)
nb_test_acc=nb_model.score(x_test,y_test)
print('train accuracy of gaussainNB:',nb_train_acc)
print('test accuracy of  gaussainNB:',nb_test_acc)
# Out:
# train accuracy of gaussainNB: 0.7730923694779116
# test accuracy of  gaussainNB: 0.78064012490242

# %%
y_pred=nb_model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#prohability of prediction
nb_model.predict_proba(x_test)
# Out:
# array([[0.56143969, 0.43856031],
#        [0.55647294, 0.44352706],
#        [0.77303403, 0.22696597],
#        ...,
#        [0.73302502, 0.26697498],
#        [0.69167493, 0.30832507],
#        [0.80855166, 0.19144834]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.98      0.85       813
#            1       0.92      0.44      0.59       468
#
#     accuracy                           0.78      1281
#    macro avg       0.84      0.71      0.72      1281
# weighted avg       0.81      0.78      0.76      1281

# %%
#cross validation
nb_score=cross_val_score(nb_model,x_train,y_train,cv=5)
print(f'naive score:{nb_score}')
print('naive_mean score:',nb_score.mean())
# Out:
# naive score:[0.78595318 0.76923077 0.77090301 0.76549414 0.76046901]
# naive_mean score: 0.7704100211200933

# %%
#6

# %% [markdown]
# # AdaBoost Algarithm

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
from sklearn .ensemble  import AdaBoostClassifier

# %%
  #base_estimator= DecisionTreeClassifier(max_depth=1)

# %%
ada_model=AdaBoostClassifier(n_estimators=50,base_estimator=DecisionTreeClassifier(max_depth=1),
                             learning_rate=0.4,random_state=1)
ada_model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1),
#                    learning_rate=0.4, random_state=1)

# %%
ada_train_acc=ada_model.score(x_train,y_train)
ada_test_acc=ada_model.score(x_test,y_test)
print('train accuracy of adaboost:',ada_train_acc)
print('test accuracy of  adaboost:',ada_test_acc)
# Out:
# train accuracy of adaboost: 0.9682061579651942
# test accuracy of  adaboost: 0.9539422326307572

# %%
y_pred=ada_model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
#model building with different  parameters
ada_model2=AdaBoostClassifier(n_estimators=50,base_estimator=RandomForestClassifier(n_estimators=50),
                               learning_rate=0.4,random_state=1)
ada_model2.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(base_estimator=RandomForestClassifier(n_estimators=50),
#                    learning_rate=0.4, random_state=1)

# %%
ada_train_acc2=ada_model2.score(x_train,y_train)
ada_test_acc2=ada_model2.score(x_test,y_test)
print('train accuracy of adaboost:',ada_train_acc2)
print('test accuracy of  adaboost:',ada_test_acc2)
# Out:
# train accuracy of adaboost: 1.0
# test accuracy of  adaboost: 0.9672131147540983

# %%
y_pred=ada_model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       813
#            1       0.93      0.94      0.94       468
#
#     accuracy                           0.95      1281
#    macro avg       0.95      0.95      0.95      1281
# weighted avg       0.95      0.95      0.95      1281

# %%
ada_score=cross_val_score(ada_model,x_train,y_train,cv=5)
print(f'adaboost_CV score:{ada_score}')
print('adaboost_mean score:',ada_score.mean())
# Out:
# adaboost_CV score:[0.95652174 0.95317726 0.96153846 0.95979899 0.97152429]
# adaboost_mean score: 0.9605121482552115

# %%
ada_param={'n_estimators':[10,30,50],
          'learning_rate':[0.01,1,0.3,0.1]}
ada_grid=GridSearchCV(ada_model,ada_param,cv=5)
ada_grid.fit(x_train,y_train)
print(f'best adaboost parameter :',ada_grid.best_params_)
print('best adaboost score:',ada_grid.best_score_)
# Out:
# best adaboost parameter : {'learning_rate': 1, 'n_estimators': 50}
# best adaboost score: 0.9682100580942619

# %%
#7

# %% [markdown]
# #  GradientBoost

# %%
from sklearn .ensemble import GradientBoostingClassifier

# %%
#model build
gbc_model=GradientBoostingClassifier(n_estimators=600,learning_rate=0.05,random_state=100)
gbc_model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, n_estimators=600,
#                            random_state=100)

# %%
gbc_train_acc=gbc_model.score(x_train,y_train)
gbc_test_acc=gbc_model.score(x_test,y_test)
print('train accuracy of gradientboost:',gbc_train_acc)
print('test accuracy of  gradientboost:',gbc_test_acc)
# Out:
# train accuracy of gradientboost: 1.0
# test accuracy of  gradientboost: 0.9789227166276346

# %%
#model predict
y_pred=gbc_model.predict(x_test)

# %%
#model build with different parameters
gbc_model2=GradientBoostingClassifier(n_estimators=300,learning_rate=0.005,random_state=50)
gbc_model2.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.005, n_estimators=300,
#                            random_state=50)

# %%
gbc_train_acc2=gbc_model2.score(x_train,y_train)
gbc_test_acc2=gbc_model2.score(x_test,y_test)
print('train accuracy of gradientboost:',gbc_train_acc2)
print('test accuracy of  gradientboost:',gbc_test_acc2)
# Out:
# train accuracy of gradientboost: 0.9742302543507363
# test accuracy of  gradientboost: 0.9562841530054644

# %%
y_pred2=gbc_model2.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       813
#            1       0.99      0.96      0.97       468
#
#     accuracy                           0.98      1281
#    macro avg       0.98      0.97      0.98      1281
# weighted avg       0.98      0.98      0.98      1281

# %%
gr_score=cross_val_score(gbc_model2,x_train,y_train,cv=5)
print(f'gradientboost_CV score:{gr_score}')
print('gradient_mean score:',gr_score.mean())
# Out:
# gradientboost_CV score:[0.9548495  0.96153846 0.98327759 0.95644891 0.96984925]
# gradient_mean score: 0.9651927418586801

# %%
gr_param={'n_estimators':[30,50,100],
          'learning_rate':[0.01,1,0.3,0.001]}
gr_grid=GridSearchCV(gbc_model2,gr_param,cv=5)
gr_grid.fit(x_train,y_train)
print(f'best gradientboost parameter :',gr_grid.best_params_)
print('best gradientboost score:',gr_grid.best_score_)
# Out:
# best gradientboost parameter : {'learning_rate': 1, 'n_estimators': 100}
# best gradientboost score: 0.981929715466967

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\abdur\Downloads\archive (3).zip")
data
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
#8

# %%
# support vector machine

# %%
#from sklearn.svm import SVC

# %%
#model bouild
#svm_model=SVC(kernel='linear')
svm_model.fit(x_train,y_train)

# %%
#svm_model.score(x_test,y_test)

# %%
#poly
svm_poly=SVC(Kernel='poly',degree=3,c=2.5)
svm_poly.fit(x_train,y_train)
svm_poly.score(x_test,y_test)

# %%
#rbf
svm_rbf=SVC()
svm_rbf.fit(x_train,y_train)
svm_rbf.score(x_test,y_test)

# %%
#sigmoid
svm_sig=SVC(Kernel='sigmoid',gamma=0.002,c=5)
svm_sig.fit(x_train,y_train)
svm_sig.score(x_test,y_test)

# %%
svm_sig2=SVC(Kernel='sigmoid',gamma=2,c=5)
svm_sig2.fit(x_train,y_train)
svm_sig2.score(x_test,y_test)

# %%
y_pred=svm_rbf.predict(x_test)

# %%
print(classification_report(y_test,y_pred))

# %%
#cross validation
svc_score=cross_val_score(svm_rbf,x_train,y_train,cv=5)
print(f'svc_CV score:{svc_score}')
print('svc_mean score:',svc_score.mean())

# %%
sv_param={'gamma':['auto','scale'],
          'c':[1,5,10,20],
          'Kernel':['linera','rbf','poly','sigmoid']}
svc_grid=GridSearchCV(svm_rbf,sv_param,cv=5)
svc_grid.fit(x_train,y_train)
print('best svc parameter :',svc_grid.best_params_)
print('best svc score:',svc_grid.best_score_)

# %%
write a function tha takes  a sentence as input  and return  new sentence with the word  in reverse vcc c

# %%
def   separate_alpha_numeric (input_string):
      alphapetts=[]
      numbers=[]
      for char in input_string:
          if char.isalpha():
              alphapets.append(char)
          elif char.isdigit():
               numbers.append(char)
    
      return alphapetts,numbers
alphapetts,numbers=separate_alpha_numeric('afsdf1234')
print('alphapetts',alphapets)    
print('numbers', numbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 11
#       8                numbers.append(char)
#      10       return alphapetts,numbers
# ---> 11 alphapetts,numbers=separate_alpha_numeric('afsdf1234')
#      12 print('alphapetts',alphapets)
#      13 print('numbers', numbers)
#
# Cell In[15], line 6, in separate_alpha_numeric(input_string)
#       4 for char in input_string:
#       5     if char.isalpha():
# ----> 6         alphapets.append(char)
#       7     elif char.isdigit():
#       8          numbers.append(char)
#
# NameError: name 'alphapets' is not defined

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\abdur\Downloads\Car_details.csv")
data
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0      Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 1          Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 2         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 3            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 4     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# ...                             ...   ...            ...        ...     ...
# 8122              Hyundai i20 Magna  2013         320000     110000  Petrol
# 8123          Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8124         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8125                Tata Indigo CR4  2013         290000      25000  Diesel
# 8126                Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
sl=data['name'].where(data['selling_price']>200000)
sl
# Out:
# 0        Skoda Rapid 1.5 TDI Ambition
# 1                                 NaN
# 2           Hyundai i20 Sportz Diesel
# 3                                 NaN
# 4       Hyundai Xcent 1.2 VTVT E Plus
#                     ...
# 8122                Hyundai i20 Magna
# 8123                              NaN
# 8124           Maruti Swift Dzire ZDi
# 8125                  Tata Indigo CR4
# 8126                  Tata Indigo CR4
# Name: name, Length: 8127, dtype: object

# %%
l1=[2,3,4,5,15]
print(l1)
# Out:
# [2, 3, 4, 5, 15]

# %%
l1[0:4]
# Out:
# [2, 3, 4, 5]

# %%
len(l1)
# Out:
# 5

# %%
l1.append(16)
l1
# Out:
# [2, 3, 4, 5, 15, 16]

# %%
l1.insert(2,'3')
l1
# Out:
# [2, 3, '3', 4, 5, 15, 16]

# %%
l1[1]=6
l1
# Out:
# [2, 6, '3', 4, 5, 15, 16]

# %%
l1.extend((17,18))
l1
# Out:
# [2, 6, '3', 4, 5, 15, 16, 17, 18]

# %%
l1.remove(2)
l1
# Out:
# [6, '3', 4, 5, 15, 16, 17, 18]

# %%
l1.pop()
l1
# Out:
# [6, '3', 4, 5, 15, 16, 17]

# %%
l1.count(4)
l1
# Out:
# [6, '3', 4, 5, 15, 16, 17]

# %%
i=5
while i< 12:
    print(i)
    i=i+1
# Out:
# 5
# 6
# 7
# 8
# 9
# 10
# 11

# %%
i=2
while i<25:
    i=i+2
    if i==8:
        continue
    print(i)
# Out:
# 4
# 6
# 10
# 12
# 14
# 16
# 18
# 20
# 22
# 24
# 26

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\abdur\Downloads\Car_details.csv")
data
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0      Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 1          Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 2         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 3            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 4     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# ...                             ...   ...            ...        ...     ...
# 8122              Hyundai i20 Magna  2013         320000     110000  Petrol
# 8123          Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8124         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8125                Tata Indigo CR4  2013         290000      25000  Diesel
# 8126                Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data.loc[data['km_driven']<100000]
# Out:
#                                    name  year  selling_price  km_driven  \
# 4         Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6                    Maruti 800 DX BSII  2001          45000       5000
# 7                      Toyota Etios VXD  2011         350000      90000
# 9       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 12                 Maruti Swift 1.3 VXi  2007         200000      80000
# ...                                 ...   ...            ...        ...
# 8118        Maruti Wagon R LXI Optional  2017         360000      80000
# 8120  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8121         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8125                    Tata Indigo CR4  2013         290000      25000
# 8126                    Tata Indigo CR4  2013         290000      25000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %%
data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
data=data.set_index('selling_price')
data
# Out:
#                                         name  year  km_driven    fuel  \
# selling_price
# 370000          Skoda Rapid 1.5 TDI Ambition  2014     120000  Diesel
# 158000              Honda City 2017-2020 EXi  2006     140000  Petrol
# 225000             Hyundai i20 Sportz Diesel  2010     127000  Diesel
# 130000                Maruti Swift VXI BSIII  2007     120000  Petrol
# 440000         Hyundai Xcent 1.2 VTVT E Plus  2017      45000  Petrol
# ...                                      ...   ...        ...     ...
# 320000                     Hyundai i20 Magna  2013     110000  Petrol
# 135000                 Hyundai Verna CRDi SX  2007     119000  Diesel
# 382000                Maruti Swift Dzire ZDi  2009     120000  Diesel
# 290000                       Tata Indigo CR4  2013      25000  Diesel
# 290000                       Tata Indigo CR4  2013      25000  Diesel
#
#               seller_type transmission                 owner     mileage  \
# selling_price
# ...

# %%
data=data.reset_index()
data
# Out:
#       selling_price                           name  year  km_driven    fuel  \
# 0            370000   Skoda Rapid 1.5 TDI Ambition  2014     120000  Diesel
# 1            158000       Honda City 2017-2020 EXi  2006     140000  Petrol
# 2            225000      Hyundai i20 Sportz Diesel  2010     127000  Diesel
# 3            130000         Maruti Swift VXI BSIII  2007     120000  Petrol
# 4            440000  Hyundai Xcent 1.2 VTVT E Plus  2017      45000  Petrol
# ...             ...                            ...   ...        ...     ...
# 8122         320000              Hyundai i20 Magna  2013     110000  Petrol
# 8123         135000          Hyundai Verna CRDi SX  2007     119000  Diesel
# 8124         382000         Maruti Swift Dzire ZDi  2009     120000  Diesel
# 8125         290000                Tata Indigo CR4  2013      25000  Diesel
# 8126         290000                Tata Indigo CR4  2013      25000  Diesel
#
# ...

# %%
data.sort_values('year',ascending=False)
data
# Out:
#       selling_price                           name  year  km_driven    fuel  \
# 0            370000   Skoda Rapid 1.5 TDI Ambition  2014     120000  Diesel
# 1            158000       Honda City 2017-2020 EXi  2006     140000  Petrol
# 2            225000      Hyundai i20 Sportz Diesel  2010     127000  Diesel
# 3            130000         Maruti Swift VXI BSIII  2007     120000  Petrol
# 4            440000  Hyundai Xcent 1.2 VTVT E Plus  2017      45000  Petrol
# ...             ...                            ...   ...        ...     ...
# 8122         320000              Hyundai i20 Magna  2013     110000  Petrol
# 8123         135000          Hyundai Verna CRDi SX  2007     119000  Diesel
# 8124         382000         Maruti Swift Dzire ZDi  2009     120000  Diesel
# 8125         290000                Tata Indigo CR4  2013      25000  Diesel
# 8126         290000                Tata Indigo CR4  2013      25000  Diesel
#
# ...

# %%
data.loc[0:1]
# Out:
#    selling_price                          name  year  km_driven    fuel  \
# 0         370000  Skoda Rapid 1.5 TDI Ambition  2014     120000  Diesel
# 1         158000      Honda City 2017-2020 EXi  2006     140000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 1  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
#
#                   torque  seats
# 0    250Nm@ 1500-2500rpm    5.0
# 1  12.7@ 2,700(kgm@ rpm)    5.0

# %%
data.isnull().sum()
# Out:
# selling_price      0
# name               0
# year               0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
data['selling_price'].max()
# Out:
# 10000000

# %%
data['mileage']=data['mileage'].fillna(23.5)
data
# Out:
#       selling_price                           name  year  km_driven    fuel  \
# 0            370000   Skoda Rapid 1.5 TDI Ambition  2014     120000  Diesel
# 1            158000       Honda City 2017-2020 EXi  2006     140000  Petrol
# 2            225000      Hyundai i20 Sportz Diesel  2010     127000  Diesel
# 3            130000         Maruti Swift VXI BSIII  2007     120000  Petrol
# 4            440000  Hyundai Xcent 1.2 VTVT E Plus  2017      45000  Petrol
# ...             ...                            ...   ...        ...     ...
# 8122         320000              Hyundai i20 Magna  2013     110000  Petrol
# 8123         135000          Hyundai Verna CRDi SX  2007     119000  Diesel
# 8124         382000         Maruti Swift Dzire ZDi  2009     120000  Diesel
# 8125         290000                Tata Indigo CR4  2013      25000  Diesel
# 8126         290000                Tata Indigo CR4  2013      25000  Diesel
#
# ...

# %%
data.isnull().sum()
# Out:
# selling_price      0
# name               0
# year               0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage            0
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
data=data.fillna({'engine':1467,'max_power':110})
data.isnull().sum()
# Out:
# selling_price      0
# name               0
# year               0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage            0
# engine             0
# max_power          0
# torque           222
# seats            221
# dtype: int64

# %%
data=data.drop(['torque','seats'],axis=1)
data.isnull().sum()
# Out:
# selling_price    0
# name             0
# year             0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# dtype: int64

# %%
data.iloc[0:1]
# Out:
#    selling_price                          name  year  km_driven    fuel  \
# 0         370000  Skoda Rapid 1.5 TDI Ambition  2014     120000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
#
#                 torque  seats
# 0  250Nm@ 1500-2500rpm    5.0

# %%
data=pd.read_csv(r"C:\Users\abdur\Downloads\Car_details.csv",header=None,
                 names=['a','b','c','d'])
data
# Out:
#                                                                                                                                  a  \
# name                         year selling_price km_driven fuel   seller_type transmission owner                mileage      engine
# Skoda Rapid 1.5 TDI Ambition 2014 370000        120000    Diesel Individual  Manual       Second Owner         21.14 kmpl  1498 CC
# Honda City 2017-2020 EXi     2006 158000        140000    Petrol Individual  Manual       Third Owner          17.7 kmpl   1497 CC
# Hyundai i20 Sportz Diesel    2010 225000        127000    Diesel Individual  Manual       First Owner          23.0 kmpl   1396 CC
# Maruti Swift VXI BSIII       2007 130000        120000    Petrol Individual  Manual       First Owner          16.1 kmpl   1298 CC
# ...                                                                                                                            ...
# ...

# %%
dict=[(101,'a',25),
      (102,'b',22),
      (102,'b',23)]
dict
# Out:
# [(101, 'a', 25), (102, 'b', 22), (102, 'b', 23)]

# %%
df=pd.DataFrame(dict,columns=['id','name','age'])
df
# Out:
#     id name  age
# 0  101    a   25
# 1  102    b   22
# 2  102    b   23

# %%
data=pd.read_
